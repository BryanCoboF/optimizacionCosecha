# %% [markdown]
# <a href="https://colab.research.google.com/github/BryanCoboF/optimizacionCosecha/blob/main/des1/optimizaCosecha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ----------------------------------------------------------
# Configuracion inicial y
# llamada a librerias

# %%
#Configuracion de librerias
# %config IPCompleter.greedy=True
# !pip install pulp
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import pulp
from pulp import LpVariable, LpProblem, LpMaximize, LpMinimize
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.10/dist-packages (2.7.0)

# %% [markdown]
# Carga de datos de Excel desde drive

# %%
from google.colab import files
from google.colab import drive

drive.mount('/content/drive') # Permite ingresar a drive desde las carpetas de drive

df = pd.read_excel("/content/drive/MyDrive/PB/ProyecciónVolDensV5.xlsx") # Carga el excel de datos de proyeccion, si se necesita cambiar el archivo se debe modificar el link


portedf = df.shape #Obtiene el numero de filas y columnas del data frame de excel
numFilasData = portedf[0]
numColumnasData = portedf[1]

print("Tamaño: ", portedf[0])

# Muestra los tipos de dato de cada columna de la base
#df.dtypes
#print('\n Tipos de datos-> \n',df.dtypes)

#Muestra las 3 primeras filas
#df.head(3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Tamaño:  327

# %% [markdown]
# Ingreso de datos deseados
#
#
# 1.   Volumen deseado (min y max) por cada mes
# 3.   Densidad deseada (min y max) por cada mes
# 2.   Edad minima y maxima deseada

# %%
# Volumen deseado cada mes
vecVolminDeseado = []
vecVolR11minDeseado = []
vecVolR11maxDeseado = []
vecVolmaxDeseado = []
vecDensminDeseada = []
vecDensmaxDeseada = []


for i in range(13):

  if i==1:
    #Enero
    #Volumen
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Enero: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    volDes = float(input("Ingrese el volumen deseado de R11 para Enero: ".format(i+1)))
    vecVolR11minDeseado.append(volDes)
    volDes = float(input("Ingrese el volumen deseado de R11 para Enero: ".format(i+1)))
    vecVolR11maxDeseado.append(volDes)

'''
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Enero: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Enero: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Enero: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)

  if i==2:
    #Febrero
    #Volumen
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Febrero: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Febrero: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Febrero: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Febrero: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)


  if i==3:
    #Marzo
    #VOLUMEN
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Marzo: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Marzo: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Marzo: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Marzo: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)


  if i==4:
    #Abril
    #VOLUMEN
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Abril: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Abril: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Abril: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Abril: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)


  if i==5:
    #Mayo
    #Volumen
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Mayo: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Mayo: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Mayo: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Mayo: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)

  if i==6:
    #Junio
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Junio: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Junio: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Junio: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Junio: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)

  if i==7:
    #Julio
    #VOLUMEN
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Julio: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Julio: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Julio: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Julio: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)

  if i==8:
    #Agosto
    #VOLUMEN
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Agosto: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Agosto: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Agosto: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Agosto: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)


  if i==9:
    #Septiembre
    #VOLUMEN
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Septiembre: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Septiembre: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Septiembre: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Septiembre: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)

  if i==10:
    #Octubre
    #VOLUMEN
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Octubre: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Octubre: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Octubre: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Octubre: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)

  if i==11:
    #Noviembre
    #VOLUMEN
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Noviembre: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Noviembre: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Noviembre: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Noviembre: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)

  if i==12:
    #Diciembre
    #VOLUMEN
    # volumen minimo deseado
    volDes = float(input("Ingrese el volumen minimo deseado de Diciembre: ".format(i+1)))
    vecVolminDeseado.append(volDes)
    # volumen maximo deseado
    volDes = float(input("Ingrese el volumen maximo deseado de Diciembre: ".format(i+1)))
    vecVolmaxDeseado.append(volDes)

    #Densidad
    # densidad minima deseada
    densDes = float(input("Ingrese la densidad minima deseada de Diciembre: ".format(i+1)))
    vecDensminDeseada.append(densDes)
    # densidad maxima deseada
    densDes = float(input("Ingrese la densidad maxima deseada de Diciembre: ".format(i+1)))
    vecDensmaxDeseada.append(densDes)
'''

#Ingreso de edad deseada
edadMinDes = float(input("Ingrese la edad minima de cosecha : "))
# Out:
# Ingrese el volumen minimo deseado de Enero: 3500000
# Ingrese el volumen deseado de R11 para Enero: 1500000
# Ingrese el volumen deseado de R11 para Enero: 1750000
# Ingrese la edad minima de cosecha : 27

# %% [markdown]
# OBTENCION  DE DATOS DEL EXCEL
# CREACION DE Diccionarios Y VECTORES
#
# *   Rendimientos proyectados por mes
# *   Edades por cada mes
# *   Areas Netas de lote
# *   Areas totales de lote (permite calcular rendimiento area plantada)
# *   Matrices de % de categoria de densidad %R11, %R8, %R9
# *   Matriz de promedios de densidad  por categoria PromR11, PromR8, PromR9
# *   Matriz de volumen por mes

# %%
# Obtencion de datos de sitio Lote
colSitioLote = df['Sitio-Lote']

# Obtencion de datos area neta
colAreaNeta = df['Área Neta del Lote (Ha)']
#vecAreaNeta = np.array(colAreaNeta)
areaMax = dict(zip(colSitioLote,colAreaNeta)) #Creacion del diccionario del area neta de cada sitio-lote  {'CEB-041.22': 11.07,....}

# ------------- Obtencion de datos de edad -----------------
# Crea el data frame con los datos de cada mes
# Crea un diccionario por cada mes con los datos por sitio-lote
#Enero
colEdadEne = df['Edad ENE 2024']
dictEdadEne = dict(zip(colSitioLote,colEdadEne))
#Febrero
colEdadFeb = df['Edad FEB 2024']
dictEdadFeb = dict(zip(colSitioLote,colEdadFeb))
#Marzo
colEdadMar = df['Edad MAR 2024']
dictEdadMar = dict(zip(colSitioLote,colEdadMar))
#Abril
colEdadAbr = df['Edad ABR 2024']
dictEdadAbr = dict(zip(colSitioLote,colEdadAbr))
#Mayo
colEdadMay = df['Edad MAY 2024']
dictEdadMay = dict(zip(colSitioLote,colEdadMay))
#Junio
colEdadJun = df['Edad JUN 2024']
dictEdadJun = dict(zip(colSitioLote,colEdadJun))
#Julio
colEdadJul = df['Edad JUL 2024']
dictEdadJul = dict(zip(colSitioLote,colEdadJul))
#Agosto
colEdadAgo = df['Edad AGO 2024']
dictEdadAgo = dict(zip(colSitioLote,colEdadAgo))
#Septiembre
colEdadSep = df['Edad SEP 2024']
dictEdadSep = dict(zip(colSitioLote,colEdadSep))
#Octubre
colEdadOct = df['Edad OCT 2024']
dictEdadOct = dict(zip(colSitioLote,colEdadOct))
#Noviembre
colEdadNov = df['Edad NOV 2024']
dictEdadNov = dict(zip(colSitioLote,colEdadNov))
#Diciembre
colEdadDic = df['Edad DIC 2024']
dictEdadDic = dict(zip(colSitioLote,colEdadDic))

#--------OBTENCION DE DATOS DE RENDIMIENTO ----------------
# Obtiene los datos de rendimiento del data frame de excel de cada mes proyectado Y CRE un diccionario por cada mes  con sitio-lote y rendimiento
#Enero
colRendProyEne = df['Rend ENE 2024']
rend_Ene = dict(zip(colSitioLote,colRendProyEne)) #crea diccionario de rendimientos proyectados de enero
rend_EneAux = dict(zip(colSitioLote,colRendProyEne)) #Crea diccionario auxiliar para definir las restricciones previo a optimizar(edad, accesibilidad)

#Febrero
colRendProyFeb = df['Rend FEB 2024']
rend_Feb = dict(zip(colSitioLote,colRendProyFeb)) #crea diccionario de rendimientos proyectados de febrero
rend_FebAux = dict(zip(colSitioLote,colRendProyFeb)) #Auxiliar

#Marzo
colRendProyMar = df['Rend MAR 2024']
rend_Mar = dict(zip(colSitioLote,colRendProyMar)) #crea diccionario de rendimientos proyectados de Marzo
rend_MarAux = dict(zip(colSitioLote,colRendProyMar)) #Auxiliar

#Abril
colRendProyAbr = df['Rend ABR 2024']
rend_Abr = dict(zip(colSitioLote,colRendProyAbr)) #crea diccionario de rendimientos proyectados de Abril
rend_AbrAux = dict(zip(colSitioLote,colRendProyAbr)) #Auxiliar

#Mayo
colRendProyMay = df['Rend MAY 2024']
rend_May = dict(zip(colSitioLote,colRendProyMay)) #crea diccionario de rendimientos proyectados de Mayo
rend_MayAux = dict(zip(colSitioLote,colRendProyMay)) #Auxiliar

#Junio
colRendProyJun = df['Rend JUN 2024']
rend_Jun = dict(zip(colSitioLote,colRendProyJun)) #crea diccionario de rendimientos proyectados de Junio
rend_JunAux = dict(zip(colSitioLote,colRendProyJun)) #Auxiliar

#Julio
colRendProyJul = df['Rend JUL 2024']
rend_Jul = dict(zip(colSitioLote,colRendProyJul)) #crea diccionario de rendimientos proyectados de Julio
rend_JulAux = dict(zip(colSitioLote,colRendProyJul)) #Auxiliar

#Agosto
colRendProyAgo = df['Rend AGO 2024']
rend_Ago = dict(zip(colSitioLote,colRendProyAgo)) #crea diccionario de rendimientos proyectados de Agosto
rend_AgoAux = dict(zip(colSitioLote,colRendProyAgo)) #Auxiliar

#Septiembre
colRendProySep = df['Rend SEP 2024']
rend_Sep = dict(zip(colSitioLote,colRendProySep)) #crea diccionario de rendimientos proyectados de Septiembre
rend_SepAux = dict(zip(colSitioLote,colRendProySep))  #Auxiliar

#Octubre
colRendProyOct = df['Rend OCT 2024']
rend_Oct = dict(zip(colSitioLote,colRendProyOct)) #crea diccionario de rendimientos proyectados de Octubre
rend_OctAux = dict(zip(colSitioLote,colRendProyOct)) #Auxiliar

#Noviembre
colRendProyNov = df['Rend NOV 2024']
rend_Nov = dict(zip(colSitioLote,colRendProyNov)) #crea diccionario de rendimientos proyectados de Noviembre
rend_NovAux = dict(zip(colSitioLote,colRendProyNov)) #Auxiliar

#Dicimebre
colRendProyDic = df['Rend DIC 2024']
rend_Dic = dict(zip(colSitioLote,colRendProyDic)) #crea diccionario de rendimientos proyectados de Diciembre
rend_DicAux = dict(zip(colSitioLote,colRendProyDic)) #Auxiliar


# ---------OBTENCION DE DATOS DE ACCESIBILIDAD------------
colAccesibilidad = df['Accesibilidad']
dictAccesibilidad = dict(zip(colSitioLote,colAccesibilidad))


# ---------OBTENCION DE DATOS DE PORCENTAJE DE R11
#Enero
colPorcR11Ene = df['%R11 ENE 2024']
dictPorcR11Ene = dict(zip(colSitioLote,colPorcR11Ene))

# %% [markdown]
# RESTRICCION DE EDAD DE COSECHA Y ACCESIBILIDAD

# %%
# Pone en 0 los valores de los rendimientos de cada mes cuando la edad es menor a la minima definida
for valor in colSitioLote:
  #Enero
  if dictEdadEne[valor]<edadMinDes:
    rend_EneAux[valor] = 0
  #Frebrero
  if dictEdadFeb[valor]<edadMinDes:
    rend_FebAux[valor] = 0
  #Marzo
  if dictEdadMar[valor]<edadMinDes:
    rend_MarAux[valor] = 0
  #Abril
  if dictEdadAbr[valor]<edadMinDes:
    rend_AbrAux[valor] = 0
  #Mayo
  if dictEdadMay[valor]<edadMinDes:
    rend_MayAux[valor] = 0
  #Junio
  if dictEdadJun[valor]<edadMinDes:
    rend_JunAux[valor] = 0
  #Julio
  if dictEdadJul[valor]<edadMinDes:
    rend_JulAux[valor] = 0
  #Agosto
  if dictEdadAgo[valor]<edadMinDes:
    rend_AgoAux[valor] = 0
  #Septiembre
  if dictEdadSep[valor]<edadMinDes:
    rend_SepAux[valor] = 0
  #Octubre
  if dictEdadOct[valor]<edadMinDes:
    rend_OctAux[valor] = 0
  #Noviembre
  if dictEdadNov[valor]<edadMinDes:
    rend_NovAux[valor] = 0
  #Diciembre
  if dictEdadDic[valor]<edadMinDes:
    rend_DicAux[valor] = 0
    print("Original->", rend_Dic[valor], "- Restringido Edad-> ", rend_DicAux[valor])
  else:
    print("Original->", rend_Dic[valor], "- Restringido Edad-> ", rend_DicAux[valor])
# Out:
# Original-> 12594.377163120735 - Restringido Edad->  12594.377163120735
# Original-> 13256.133918250425 - Restringido Edad->  13256.133918250425
# Original-> 13459.751381367254 - Restringido Edad->  13459.751381367254
# Original-> 13743.008881002372 - Restringido Edad->  13743.008881002372
# Original-> 13692.234040757483 - Restringido Edad->  13692.234040757483
# Original-> 6538.110037327755 - Restringido Edad->  0
# Original-> 6115.2047742629475 - Restringido Edad->  0
# Original-> 6619.6894419103155 - Restringido Edad->  0
# Original-> 6595.097033313544 - Restringido Edad->  0
# Original-> 6619.6894419103155 - Restringido Edad->  0
# Original-> 6718.059076297407 - Restringido Edad->  0
# Original-> 6662.49393822917 - Restringido Edad->  0
# Original-> 17647.87170982572 - Restringido Edad->  17647.87170982572
# Original-> 6388.849356246059 - Restringido Edad->  0
# Original-> 14425.928724541813 - Restringido Edad->  14425.928724541813
# Original-> 12529.650949233413 - Restringido Edad->  12529.650949233413
# Original-> 6521.319807523229 - Restringido Edad->  0
# Original-> 17992.676096848594 - Restringido Edad->  17992.676096848594
# Original-> 6463.479696786908 - Restringido Edad->  0
# Original-> 6314.21901570521 - Restringido Edad->  0
# Original-> 17690.28817747661 - Restringido Edad->  17690.28817747661
# Original-> 6619.6894419103155 - Restringido Edad->  0
# Original-> 6570.504624716772 - Restringido Edad->  0
# Original-> 18126.010619415796 - Restringido Edad->  18126.010619415796
# Original-> 20856.249047117817 - Restringido Edad->  20856.249047117817
# Original-> 18851.771217469708 - Restringido Edad->  18851.771217469708
# Original-> 19526.92483015454 - Restringido Edad->  19526.92483015454
# Original-> 16592.84799827399 - Restringido Edad->  16592.84799827399
# Original-> 19448.04484137232 - Restringido Edad->  19448.04484137232
# Original-> 20935.07488692674 - Restringido Edad->  20935.07488692674
# Original-> 19168.07098147883 - Restringido Edad->  19168.07098147883
# Original-> 16797.086171587933 - Restringido Edad->  16797.086171587933
# Original-> 19797.54016407948 - Restringido Edad->  19797.54016407948
# Original-> 23462.81538671613 - Restringido Edad->  23462.81538671613
# Original-> 23939.014987515486 - Restringido Edad->  23939.014987515486

# %% [markdown]
# MODELO DE OPTIMIZACION

# %%
#Definicion del modelo
optCosecha = pulp.LpProblem('OptimizacionCosecha',pulp.LpMinimize) #Inicialmente busca minimizar el area de cosecha para obtener el volumen necesario para Enero

# VARIABLE DE DECISION (AREA A COSECHAR)
area_a_cosechar_Ene = pulp.LpVariable.dict("VariableAreaCosecha",colSitioLote, lowBound=0, cat='Continuous')

#print(area_a_cosechar_Ene.values())

#FUNCION OBJETIVO
optCosecha += sum([rend_EneAux[i]*area_a_cosechar_Ene[i] for i in colSitioLote]) # Funcion objetivo obtiene volumen con las areas definidas

# RESTRICCIONES
#Volumen deseado por mes
optCosecha += sum([rend_EneAux[i]*area_a_cosechar_Ene[i] for i in colSitioLote]) >= vecVolminDeseado[0] #Volumen deseado para Enero
optCosecha += sum([rend_EneAux[i]*area_a_cosechar_Ene[i]*dictPorcR11Ene[i] for i in colSitioLote]) >= vecVolR11minDeseado[0] #Volumen deseado minimo R11 para Enero
optCosecha += sum([rend_EneAux[i]*area_a_cosechar_Ene[i]*dictPorcR11Ene[i] for i in colSitioLote]) <= vecVolR11maxDeseado[0] #Volumen deseado maximo R11 para Enero

for i in area_a_cosechar_Ene:
  #Restringe que el area a cosechar resultante no sea mayor al area de cada lote
  optCosecha += area_a_cosechar_Ene[i]>= 0
  optCosecha += area_a_cosechar_Ene[i]<= areaMax[i]


#Resolucion
optCosecha.solve()


a=1
resAreaCosecha = []
for areaEneCosecha in colSitioLote:

  resAreaCosecha.append(area_a_cosechar_Ene[areaEneCosecha].value())

  print("Area a cosechar: ", a, " - ",  areaEneCosecha, "- >", area_a_cosechar_Ene[areaEneCosecha].value())
  a=a+1

resVolTotal = sum([rend_EneAux[i]*area_a_cosechar_Ene[i].value() for i in colSitioLote])
resVolR11 = sum([rend_EneAux[i]*area_a_cosechar_Ene[i].value()*dictPorcR11Ene[i] for i in colSitioLote])
print(resVolTotal)
print(resVolR11)
# Out:
# Area a cosechar:  1  -  CEB-041.22 - > 0.0
# Area a cosechar:  2  -  CEB-042.22 - > 0.0
# Area a cosechar:  3  -  CEB-043.22 - > 0.0
# Area a cosechar:  4  -  FC-011.22 - > 0.0
# Area a cosechar:  5  -  FC-012.22 - > 0.0
# Area a cosechar:  6  -  FC-021.22 - > 0.0
# Area a cosechar:  7  -  FC-0210.22 - > 0.0
# Area a cosechar:  8  -  FC-0211.22 - > 0.0
# Area a cosechar:  9  -  FC-0212.22 - > 0.0
# Area a cosechar:  10  -  FC-0213.22 - > 0.0
# Area a cosechar:  11  -  FC-0215.22 - > 0.0
# Area a cosechar:  12  -  FC-022.22 - > 0.0
# Area a cosechar:  13  -  FC-023.21.R - > 0.0
# Area a cosechar:  14  -  FC-023.22 - > 0.0
# Area a cosechar:  15  -  FC-024.21.R - > 0.0
# Area a cosechar:  16  -  FC-024.21.A.R - > 0.0
# Area a cosechar:  17  -  FC-024.22 - > 0.0
# Area a cosechar:  18  -  FC-025.21.R - > 0.0
# Area a cosechar:  19  -  FC-025.22 - > 0.0
# Area a cosechar:  20  -  FC-026.22 - > 0.0
# Area a cosechar:  21  -  FC-027.21.R - > 0.0
# Area a cosechar:  22  -  FC-027.22 - > 0.0
# Area a cosechar:  23  -  FC-029.22 - > 0.0
# Area a cosechar:  24  -  FC-031.21 - > 0.0
# Area a cosechar:  25  -  FC-032.21 - > 0.0
# Area a cosechar:  26  -  FC-032.21.A - > 0.0
# Area a cosechar:  27  -  FC-033.21 - > 0.0
# Area a cosechar:  28  -  FC-033.21.LY - > 0.0
# Area a cosechar:  29  -  FC-071.21 - > 0.0
# Area a cosechar:  30  -  FC-071.21.A - > 0.0
# Area a cosechar:  31  -  FC-072.21 - > 0.0
# Area a cosechar:  32  -  FC-072.21.A - > 0.0
# Area a cosechar:  33  -  FM-111.21 - > 0.0
# Area a cosechar:  34  -  FM-112.21 - > 0.0
# Area a cosechar:  35  -  FM-113.21 - > 0.0
# Area a cosechar:  36  -  FM-114.21 - > 0.0
# Area a cosechar:  37  -  FM-151.21 - > 0.0
# Area a cosechar:  38  -  FM-151.21.LY - > 0.0
# Area a cosechar:  39  -  FM-152.21 - > 0.0
# Area a cosechar:  40  -  FM-154.21 - > 0.0
# Area a cosechar:  41  -  FM-201.22 - > 0.0
# Area a cosechar:  42  -  FM-202.22 - > 0.0
# Area a cosechar:  43  -  FM-203.22 - > 0.0
# Area a cosechar:  44  -  MS-061.21 - > 0.0
# Area a cosechar:  45  -  MS-062.21 - > 0.0
# Area a cosechar:  46  -  MS-062.21.A - > 0.0
# Area a cosechar:  47  -  MS-062.21.B - > 0.0
# Area a cosechar:  48  -  MS-062.21.C - > 0.0
# Area a cosechar:  49  -  MS-062.21.D - > 0.0
# Area a cosechar:  50  -  MS-062.21.E - > 0.0
# Area a cosechar:  51  -  MS-063.21 - > 0.0
# Area a cosechar:  52  -  MS-071.21 - > 0.0
# Area a cosechar:  53  -  MS-072.21 - > 0.0
# Area a cosechar:  54  -  MS-101.21 - > 0.0
# Area a cosechar:  55  -  MS-102.21 - > 0.0
# Area a cosechar:  56  -  MS-102.21.A - > 0.0
# Area a cosechar:  57  -  MS-102.21.B - > 0.0
# Area a cosechar:  58  -  MS-102.21.C - > 0.0
# Area a cosechar:  59  -  MS-102.21.D - > 0.0
# Area a cosechar:  60  -  MS-102.21.E - > 0.0
# Area a cosechar:  61  -  MS-103.21 - > 0.0
# Area a cosechar:  62  -  MS-104.21 - > 0.0
# Area a cosechar:  63  -  MS-104.21.A - > 0.0
# Area a cosechar:  64  -  MS-105.21 - > 0.0
# Area a cosechar:  65  -  MS-121.21 - > 0.0
# Area a cosechar:  66  -  MS-122.21 - > 0.0
# Area a cosechar:  67  -  MS-122.21.A - > 0.0
# Area a cosechar:  68  -  MS-123.21 - > 0.0
# Area a cosechar:  69  -  MS-124.21 - > 0.0
# Area a cosechar:  70  -  MS-124.21.A - > 0.0
# Area a cosechar:  71  -  MS-135.21 - > 0.0
# Area a cosechar:  72  -  MS-136.21 - > 0.0
# Area a cosechar:  73  -  MS-136.21.A - > 0.0
# Area a cosechar:  74  -  MS-137.21 - > 0.0
# Area a cosechar:  75  -  MS-138.21 - > 0.0
# Area a cosechar:  76  -  MS-141.21 - > 0.0
# Area a cosechar:  77  -  MS-141.21.A - > 0.0
# Area a cosechar:  78  -  MS-142.21 - > 0.0
# Area a cosechar:  79  -  MS-143.21 - > 0.0
# Area a cosechar:  80  -  MS-142.21.ES - > 0.0
# Area a cosechar:  81  -  MS-142.21.ES.A - > 0.0
# Area a cosechar:  82  -  MS-143.21.ES - > 0.0
# Area a cosechar:  83  -  MS-143.21.ES.A - > 0.0
# Area a cosechar:  84  -  MS-144.21.ES - > 0.0
# Area a cosechar:  85  -  MS-144.21 - > 0.0
# Area a cosechar:  86  -  MS-151.2 - > 0.0
# Area a cosechar:  87  -  MS-151.20.A - > 0.0
# Area a cosechar:  88  -  MS-152.2 - > 0.0
# Area a cosechar:  89  -  MS-153.2 - > 0.0
# Area a cosechar:  90  -  MS-153.20.A - > 0.0
# Area a cosechar:  91  -  MS-154.2 - > 0.0
# Area a cosechar:  92  -  MS-155.2 - > 0.0
# Area a cosechar:  93  -  MS-162.20.A - > 0.0
# Area a cosechar:  94  -  MS-163.2 - > 0.0
# Area a cosechar:  95  -  MS-163.20.A - > 0.0
# Area a cosechar:  96  -  PB-151.22 - > 0.0
# Area a cosechar:  97  -  PB-152.22 - > 0.0
# Area a cosechar:  98  -  PB-153.22 - > 0.0
# Area a cosechar:  99  -  PB-161.21 - > 0.0
# Area a cosechar:  100  -  PB-162.21 - > 0.0
# Area a cosechar:  101  -  PB-162.21.A - > 0.0
# Area a cosechar:  102  -  PB-163.21 - > 0.0
# Area a cosechar:  103  -  PB-163.21.A - > 0.0
# Area a cosechar:  104  -  PB-201.22 - > 0.0
# Area a cosechar:  105  -  PB-202.22 - > 0.0
# Area a cosechar:  106  -  PB-251.22 - > 0.0
# Area a cosechar:  107  -  PB-252.22 - > 0.0
# Area a cosechar:  108  -  PB-252.22.A - > 0.0
# Area a cosechar:  109  -  PB-274.21 - > 0.0
# Area a cosechar:  110  -  PB-274.21.A - > 0.0
# Area a cosechar:  111  -  PB-274.21.B - > 0.0
# Area a cosechar:  112  -  PB-275.21 - > 0.0
# Area a cosechar:  113  -  PB-275.21.A - > 0.0
# Area a cosechar:  114  -  PB-371.22 - > 0.0
# Area a cosechar:  115  -  PB-371.22.A - > 0.0
# Area a cosechar:  116  -  PB-372.22 - > 0.0
# Area a cosechar:  117  -  PB-382.21 - > 0.0
# Area a cosechar:  118  -  PB-383.21 - > 0.0
# Area a cosechar:  119  -  PB-383.21.A - > 0.0
# Area a cosechar:  120  -  PB-382.21.LY - > 0.0
# Area a cosechar:  121  -  PB-383.21.LY - > 0.0
# Area a cosechar:  122  -  PB-394.21 - > 0.0
# Area a cosechar:  123  -  PB-394.21.A - > 0.0
# Area a cosechar:  124  -  PB-395.21 - > 0.0
# Area a cosechar:  125  -  PB-395.21.A - > 0.0
# Area a cosechar:  126  -  PB-396.21 - > 0.0
# Area a cosechar:  127  -  PB-401.21 - > 0.0
# Area a cosechar:  128  -  PB-402.21 - > 0.0
# Area a cosechar:  129  -  PB-403.21 - > 0.0
# Area a cosechar:  130  -  PB-441.21 - > 0.0
# Area a cosechar:  131  -  PB-442.21 - > 0.0
# Area a cosechar:  132  -  PB-443.21 - > 0.0
# Area a cosechar:  133  -  PB-443.21.A - > 0.0
# Area a cosechar:  134  -  PB-444.21 - > 0.0
# Area a cosechar:  135  -  PB-445.21 - > 0.0
# Area a cosechar:  136  -  PB-446.21 - > 0.0
# Area a cosechar:  137  -  PB-446.21.LY - > 0.0
# Area a cosechar:  138  -  PB-451.22 - > 0.0
# Area a cosechar:  139  -  PB-452.22 - > 0.0
# Area a cosechar:  140  -  PB-453.22 - > 0.0
# Area a cosechar:  141  -  PB-461.22 - > 0.0
# Area a cosechar:  142  -  PB-462.22 - > 0.0
# Area a cosechar:  143  -  PB-491.21 - > 0.0
# Area a cosechar:  144  -  PB-4910.21 - > 0.0
# Area a cosechar:  145  -  PB-4910.21.A - > 0.0
# Area a cosechar:  146  -  PB-4911.21 - > 0.0
# Area a cosechar:  147  -  PB-4911.21.A - > 0.0
# Area a cosechar:  148  -  PB-4911.21.B - > 0.0
# Area a cosechar:  149  -  PB-4912.21 - > 0.0
# Area a cosechar:  150  -  PB-493.21 - > 0.0
# Area a cosechar:  151  -  PB-494.21 - > 0.0
# Area a cosechar:  152  -  PB-495.21 - > 0.0
# Area a cosechar:  153  -  PB-495.21.A - > 0.0
# Area a cosechar:  154  -  PB-495.21.B - > 0.0
# Area a cosechar:  155  -  PB-496.21 - > 0.0
# Area a cosechar:  156  -  PB-496.21.A - > 0.0
# Area a cosechar:  157  -  PB-496.21.B - > 0.0
# Area a cosechar:  158  -  PB-497.21 - > 0.0
# Area a cosechar:  159  -  PB-498.21 - > 0.0
# Area a cosechar:  160  -  PB-499.21 - > 0.0
# Area a cosechar:  161  -  PB-499.21.A - > 0.0
# Area a cosechar:  162  -  PB-499.21.B - > 0.0
# Area a cosechar:  163  -  PB-499.21.C - > 0.0
# Area a cosechar:  164  -  PB-537.22 - > 0.0
# Area a cosechar:  165  -  PB-535.22 - > 0.0
# Area a cosechar:  166  -  PB-5510.2 - > 0.0
# Area a cosechar:  167  -  PB-5511.2 - > 0.0
# Area a cosechar:  168  -  PB-5512.21 - > 0.0
# Area a cosechar:  169  -  PB-5513.2 - > 0.0
# Area a cosechar:  170  -  PB-5515.21 - > 0.0
# Area a cosechar:  171  -  PB-5516.2 - > 0.0
# Area a cosechar:  172  -  PB-5517.2 - > 0.0
# Area a cosechar:  173  -  PB-5518.2 - > 21.67
# Area a cosechar:  174  -  PB-5519.2 - > 21.17
# Area a cosechar:  175  -  PB-558.2 - > 0.0
# Area a cosechar:  176  -  PB-559.2 - > 0.0
# Area a cosechar:  177  -  PB-554.22 - > 0.0
# Area a cosechar:  178  -  PB-5610.2 - > 0.0
# Area a cosechar:  179  -  PB-5611.2 - > 0.0
# Area a cosechar:  180  -  PB-5612.2 - > 0.0
# Area a cosechar:  181  -  PB-5613.21 - > 0.0
# Area a cosechar:  182  -  PB-565.2 - > 0.0
# Area a cosechar:  183  -  PB-5623.21 - > 0.0
# Area a cosechar:  184  -  PB-563.2 - > 657.52227
# Area a cosechar:  185  -  PB-564.2 - > 9.75
# Area a cosechar:  186  -  PB-566.2 - > 0.0
# Area a cosechar:  187  -  PB-568.2 - > 18.65
# Area a cosechar:  188  -  PB-569.21 - > 0.0
# Area a cosechar:  189  -  PB-681.21 - > 0.0
# Area a cosechar:  190  -  PB-682.21 - > 0.0
# Area a cosechar:  191  -  PB-682.21.A - > 0.0
# Area a cosechar:  192  -  PB-683.21 - > 0.0
# Area a cosechar:  193  -  PB-683.21.A - > 0.0
# Area a cosechar:  194  -  PB-691.21 - > 0.0
# Area a cosechar:  195  -  PB-6910.21 - > 0.0
# Area a cosechar:  196  -  PB-6910.21.A - > 0.0
# Area a cosechar:  197  -  PB-6911.21 - > 0.0
# Area a cosechar:  198  -  PB-6911.21.A - > 0.0
# Area a cosechar:  199  -  PB-692.21 - > 0.0
# Area a cosechar:  200  -  PB-693.21 - > 0.0
# Area a cosechar:  201  -  PB-693.21.A - > 0.0
# Area a cosechar:  202  -  PB-694.21 - > 0.0
# Area a cosechar:  203  -  PB-695.21 - > 0.0
# Area a cosechar:  204  -  PB-696.21 - > 0.0
# Area a cosechar:  205  -  PB-696.21.A - > 0.0
# Area a cosechar:  206  -  PB-697.21 - > 0.0
# Area a cosechar:  207  -  PB-697.21.A - > 0.0
# Area a cosechar:  208  -  PB-698.21 - > 0.0
# Area a cosechar:  209  -  PB-699.21 - > 0.0
# Area a cosechar:  210  -  PB-699.21.A - > 0.0
# Area a cosechar:  211  -  PB-699.21.B - > 0.0
# Area a cosechar:  212  -  PB-831.21 - > 0.0
# Area a cosechar:  213  -  PB-8310.21 - > 0.0
# Area a cosechar:  214  -  PB-8311.21 - > 0.0
# Area a cosechar:  215  -  PB-8312.21 - > 0.0
# Area a cosechar:  216  -  PB-8313.21 - > 0.0
# Area a cosechar:  217  -  PB-8314.21 - > 0.0
# Area a cosechar:  218  -  PB-8315.21 - > 0.0
# Area a cosechar:  219  -  PB-832.21 - > 0.0
# Area a cosechar:  220  -  PB-833.21 - > 0.0
# Area a cosechar:  221  -  PB-834.21 - > 0.0
# Area a cosechar:  222  -  PB-835.21 - > 0.0
# Area a cosechar:  223  -  PB-836.21 - > 0.0
# Area a cosechar:  224  -  PB-837.21 - > 0.0
# Area a cosechar:  225  -  PB-838.21 - > 0.0
# Area a cosechar:  226  -  PB-839.21 - > 0.0
# Area a cosechar:  227  -  PB-841.21 - > 0.0
# Area a cosechar:  228  -  PB-8410.22 - > 0.0
# Area a cosechar:  229  -  PB-8411.22 - > 0.0
# Area a cosechar:  230  -  PB-8412.22 - > 0.0
# Area a cosechar:  231  -  PB-8413.22 - > 0.0
# Area a cosechar:  232  -  PB-8414.22 - > 0.0
# Area a cosechar:  233  -  PB-8415.22 - > 0.0
# Area a cosechar:  234  -  PB-8416.22 - > 0.0
# Area a cosechar:  235  -  PB-8416.22.A - > 0.0
# Area a cosechar:  236  -  PB-8417.22 - > 0.0
# Area a cosechar:  237  -  PB-842.21 - > 0.0
# Area a cosechar:  238  -  PB-843.21 - > 0.0
# Area a cosechar:  239  -  PB-844.21 - > 0.0
# Area a cosechar:  240  -  PB-845.21 - > 0.0
# Area a cosechar:  241  -  PB-846.21 - > 0.0
# Area a cosechar:  242  -  PB-847.21 - > 0.0
# Area a cosechar:  243  -  PB-848.21 - > 0.0
# Area a cosechar:  244  -  PB-849.21 - > 0.0
# Area a cosechar:  245  -  PB-851.22 - > 0.0
# Area a cosechar:  246  -  PB-852.22 - > 0.0
# Area a cosechar:  247  -  PB-853.22 - > 0.0
# Area a cosechar:  248  -  PB-861.22 - > 0.0
# Area a cosechar:  249  -  PB-862.22 - > 0.0
# Area a cosechar:  250  -  PB-863.22 - > 0.0
# Area a cosechar:  251  -  PB-871.22 - > 0.0
# Area a cosechar:  252  -  PB-872.22 - > 0.0
# Area a cosechar:  253  -  PR-021.22 - > 0.0
# Area a cosechar:  254  -  PR-022.22 - > 0.0
# Area a cosechar:  255  -  PR-022.22.A - > 0.0
# Area a cosechar:  256  -  PR-023.22 - > 0.0
# Area a cosechar:  257  -  PR-024.22 - > 0.0
# Area a cosechar:  258  -  PR-025.22 - > 0.0
# Area a cosechar:  259  -  PR-026.22 - > 0.0
# Area a cosechar:  260  -  PR-027.22 - > 0.0
# Area a cosechar:  261  -  RD-051.22 - > 0.0
# Area a cosechar:  262  -  RD-052.22 - > 0.0
# Area a cosechar:  263  -  RD-053.22 - > 0.0
# Area a cosechar:  264  -  RD-054.22 - > 0.0
# Area a cosechar:  265  -  FC-041.21 - > 0.0
# Area a cosechar:  266  -  FC-041.21.A - > 0.0
# Area a cosechar:  267  -  FC-042.21 - > 0.0
# Area a cosechar:  268  -  FC-042.21.A - > 0.0
# Area a cosechar:  269  -  FC-111.21 - > 0.0
# Area a cosechar:  270  -  FC-112.21 - > 0.0
# Area a cosechar:  271  -  RD-021.22 - > 0.0
# Area a cosechar:  272  -  RD-022.22 - > 0.0
# Area a cosechar:  273  -  RD-023.22 - > 0.0
# Area a cosechar:  274  -  RD-024.22 - > 0.0
# Area a cosechar:  275  -  RD-025.22 - > 0.0
# Area a cosechar:  276  -  RD-026.20.R - > 0.0
# Area a cosechar:  277  -  RD-026.22 - > 0.0
# Area a cosechar:  278  -  PB-171.22 - > 0.0
# Area a cosechar:  279  -  PB-172.22 - > 0.0
# Area a cosechar:  280  -  PB-173.22 - > 0.0
# Area a cosechar:  281  -  PB-291.22 - > 0.0
# Area a cosechar:  282  -  PB-292.22 - > 0.0
# Area a cosechar:  283  -  RD-011.22 - > 0.0
# Area a cosechar:  284  -  RD-012.22 - > 0.0
# Area a cosechar:  285  -  RD-013.22 - > 0.0
# Area a cosechar:  286  -  PB-01.1.22 - > 0.0
# Area a cosechar:  287  -  PB-01.2.22 - > 0.0
# Area a cosechar:  288  -  PB-01.3.22 - > 0.0
# Area a cosechar:  289  -  FC-09.1.22 - > 0.0
# Area a cosechar:  290  -  FC-09.2.22 - > 0.0
# Area a cosechar:  291  -  FC-09.3.22 - > 0.0
# Area a cosechar:  292  -  FM-06.1.22 - > 0.0
# Area a cosechar:  293  -  FM-06.2.22 - > 0.0
# Area a cosechar:  294  -  PB-34.3.22 - > 0.0
# Area a cosechar:  295  -  PB-34.4.22 - > 0.0
# Area a cosechar:  296  -  PB-34.5.22 - > 0.0
# Area a cosechar:  297  -  PR-04.1.22 - > 0.0
# Area a cosechar:  298  -  PR-04.2.22 - > 0.0
# Area a cosechar:  299  -  PR-04.3.22 - > 0.0
# Area a cosechar:  300  -  PR-04.4.22 - > 0.0
# Area a cosechar:  301  -  PR-04.5.22 - > 0.0
# Area a cosechar:  302  -  FM-07.1.22 - > 0.0
# Area a cosechar:  303  -  FM-07.2.22 - > 0.0
# Area a cosechar:  304  -  FM-07.3.22 - > 0.0
# Area a cosechar:  305  -  FM-07.4.22 - > 0.0
# Area a cosechar:  306  -  PR-04A.1.22 - > 0.0
# Area a cosechar:  307  -  PR-04A.2.22 - > 0.0
# Area a cosechar:  308  -  ES-011.21.ES - > 0.38
# Area a cosechar:  309  -  ES-011.21.B.ES - > 0.72
# Area a cosechar:  310  -  PB-771.21 - > 13.06
# Area a cosechar:  311  -  PB-772.21 - > 16.89
# Area a cosechar:  312  -  PB-772.21.A - > 3.24
# Area a cosechar:  313  -  PB-772.21.LY - > 2.09
# Area a cosechar:  314  -  PB-773.21 - > 18.75
# Area a cosechar:  315  -  PB-773.21.LY - > 1.81
# Area a cosechar:  316  -  FM-164.21 - > 0.0
# Area a cosechar:  317  -  PR-051.21 - > 0.0
# Area a cosechar:  318  -  PB-131.21 - > 0.0
# Area a cosechar:  319  -  PB-132.21 - > 0.0
# Area a cosechar:  320  -  PB-133.21 - > 0.0
# Area a cosechar:  321  -  PB-651.21 - > 0.0
# Area a cosechar:  322  -  PB-652.21 - > 0.0
# Area a cosechar:  323  -  PB-652.21.A - > 0.0
# Area a cosechar:  324  -  PB-652.21.B - > -56.682222
# Area a cosechar:  325  -  PB-653.21 - > 0.0
# Area a cosechar:  326  -  PB-653.21.A - > 0.0
# Area a cosechar:  327  -  PB-653.21.B - > 0.0
# 3499999.9949104767
# 1749999.9974578773

# %% [markdown]
# Creacion de archivo de excel con resultados

# %%
# Corregir, ingresar cada dato del resultado en un diccionario para luego asignar al df

dfArea_a_Cosechar = pd.DataFrame(area_a_cosechar_Ene.values(), index = colSitioLote)
